# %%
# YOLOv5 setup
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 10956, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 10956 (delta 0), reused 1 (delta 0), pack-reused 10949
# Receiving objects: 100% (10956/10956), 11.12 MiB | 27.11 MiB/s, done.
# Resolving deltas: 100% (7556/7556), done.
# /content/yolov5

# %%
# dependencies
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.10.0+cu111 (CPU)

# %%
#Roboflow Setup
from roboflow import Roboflow
rf = Roboflow(model_format="yolov5", notebook="ultralytics")
# Out:
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=yolov5&ref=ultralytics

# %%
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="s12M9GsU9O2pxumQ0n9X")
project = rf.workspace("sonny-lowe").project("the-jungle-homelessness")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in /content/datasets/The-Jungle-Homelessness-1 to yolov5pytorch: 100% [1385040 / 1385040] bytes
# Extracting Dataset Version Zip to /content/datasets/The-Jungle-Homelessness-1 in yolov5pytorch:: 100%|██████████| 104/104 [00:00<00:00, 1041.54it/s]

# %%
# %cat {dataset.location}/data.yaml
# Out:
# names:
# - Debris
# - Encampments
# nc: 2
# train: /content/datasets/The-Jungle-Homelessness-1/train/images
# val: /content/datasets/The-Jungle-Homelessness-1/valid/images

# %%
# train yolov5s
# 150 epochs
# time its performance
# %%time
# !python train.py --img 416 --batch 16 --epochs 150 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# train: weights=yolov5s.pt, cfg=, data=/content/datasets/The-Jungle-Homelessness-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-1-g66aaf51 torch 1.10.0+cu111 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 118MB/s]
#
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     18879  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 270 layers, 7025023 parameters, 7025023 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 57 weight (no decay), 60 weight, 60 bias
# albumentations: version 1.0.3 required by YOLOv5, but version 0.1.12 is currently installed
# train: Scanning '/content/datasets/The-Jungle-Homelessness-1/train/labels' images and labels...32 found, 0 missing, 1 empty, 0 corrupt: 100% 32/32 [00:00<00:00, 744.60it/s]
# train: New cache created: /content/datasets/The-Jungle-Homelessness-1/train/labels.cache
# train: Caching images (0.0GB ram): 100% 32/32 [00:00<00:00, 314.34it/s]
# val: Scanning '/content/datasets/The-Jungle-Homelessness-1/valid/labels' images and labels...9 found, 0 missing, 0 empty, 0 corrupt: 100% 9/9 [00:00<00:00, 275.55it/s]
# val: New cache created: /content/datasets/The-Jungle-Homelessness-1/valid/labels.cache
# val: Caching images (0.0GB ram): 100% 9/9 [00:00<00:00, 150.59it/s]
# Plotting labels to runs/train/exp/labels.jpg...
#
# AutoAnchor: 5.73 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 150 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      0/149        0G     0.129   0.04549   0.03076       195       416: 100% 2/2 [00:22<00:00, 11.41s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.56s/it]
#                  all          9         95    0.00351     0.0128   0.000684   0.000137
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      1/149        0G    0.1289   0.04146   0.03069       215       416: 100% 2/2 [00:19<00:00,  9.63s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.43s/it]
#                  all          9         95   0.000751     0.0217   0.000384   7.68e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      2/149        0G    0.1275    0.0448   0.03033       166       416: 100% 2/2 [00:18<00:00,  9.48s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.42s/it]
#                  all          9         95   0.000774     0.0217   0.000383   5.96e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      3/149        0G    0.1271   0.05425   0.03008       257       416: 100% 2/2 [00:18<00:00,  9.43s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.47s/it]
#                  all          9         95    0.00121     0.0346   0.000611   6.11e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      4/149        0G    0.1284   0.04365   0.03029       128       416: 100% 2/2 [00:18<00:00,  9.43s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.48s/it]
#                  all          9         95    0.00085     0.0256   0.000437   4.37e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      5/149        0G    0.1269   0.04863   0.03018       205       416: 100% 2/2 [00:18<00:00,  9.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.50s/it]
#                  all          9         95   0.000426     0.0128    0.00021    2.1e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      6/149        0G    0.1264   0.05645   0.02983       269       416: 100% 2/2 [00:18<00:00,  9.30s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.49s/it]
#                  all          9         95   0.000425     0.0128   0.000207   2.07e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      7/149        0G    0.1255   0.05972   0.02977       264       416: 100% 2/2 [00:18<00:00,  9.43s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.57s/it]
#                  all          9         95    0.00116     0.0128   0.000442   4.42e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      8/149        0G    0.1274   0.05449   0.02985       272       416: 100% 2/2 [00:19<00:00,  9.58s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.60s/it]
#                  all          9         95    0.00164     0.0128   0.000446   4.46e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      9/149        0G    0.1253   0.05899   0.02969       238       416: 100% 2/2 [00:18<00:00,  9.44s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.67s/it]
#                  all          9         95    0.00204     0.0128   0.000457   7.08e-05
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     10/149        0G    0.1243   0.05268   0.02929       197       416: 100% 2/2 [00:18<00:00,  9.48s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.74s/it]
#                  all          9         95    0.00522     0.0256   0.000887   0.000115
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     11/149        0G    0.1224   0.04831   0.02941       174       416: 100% 2/2 [00:19<00:00,  9.53s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.70s/it]
#                  all          9         95    0.00673     0.0128   0.000793   0.000154
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     12/149        0G    0.1215   0.06343   0.02904       225       416: 100% 2/2 [00:18<00:00,  9.46s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.70s/it]
#                  all          9         95    0.00828     0.0128   0.000821   0.000162
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     13/149        0G    0.1232   0.06129   0.02912       275       416: 100% 2/2 [00:18<00:00,  9.39s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.83s/it]
#                  all          9         95    0.00924     0.0128   0.000862   0.000218
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     14/149        0G     0.121   0.04805   0.02942       166       416: 100% 2/2 [00:18<00:00,  9.42s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.78s/it]
#                  all          9         95    0.00968     0.0128   0.000641   0.000285
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     15/149        0G    0.1219   0.05803    0.0287       185       416: 100% 2/2 [00:18<00:00,  9.40s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.79s/it]
#                  all          9         95    0.00782     0.0128    0.00059   0.000254
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     16/149        0G    0.1204   0.05847   0.02856       233       416: 100% 2/2 [00:18<00:00,  9.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.90s/it]
#                  all          9         95     0.0053     0.0128   0.000533   0.000273
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     17/149        0G    0.1208   0.06531   0.02849       201       416: 100% 2/2 [00:18<00:00,  9.32s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.90s/it]
#                  all          9         95    0.00466     0.0128   0.000504   0.000192
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     18/149        0G    0.1193   0.05959   0.02856       178       416: 100% 2/2 [00:18<00:00,  9.29s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.96s/it]
#                  all          9         95    0.00672     0.0256   0.000946   0.000174
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     19/149        0G    0.1195   0.05876   0.02851       179       416: 100% 2/2 [00:18<00:00,  9.31s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.02s/it]
#                  all          9         95    0.00502     0.0256    0.00107   0.000225
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     20/149        0G    0.1188   0.06894   0.02852       223       416: 100% 2/2 [00:18<00:00,  9.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.07s/it]
#                  all          9         95    0.00416     0.0256   0.000832   0.000194
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     21/149        0G    0.1185   0.07073   0.02754       224       416: 100% 2/2 [00:18<00:00,  9.33s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.16s/it]
#                  all          9         95    0.00351     0.0256   0.000963   0.000255
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     22/149        0G    0.1179   0.05435   0.02802       154       416: 100% 2/2 [00:18<00:00,  9.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.19s/it]
#                  all          9         95     0.0044     0.0385    0.00132   0.000235
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     23/149        0G    0.1157   0.04905   0.02746       167       416: 100% 2/2 [00:18<00:00,  9.44s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.30s/it]
#                  all          9         95    0.00342     0.0385     0.0011   0.000175
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     24/149        0G    0.1152   0.06508   0.02722       192       416: 100% 2/2 [00:18<00:00,  9.32s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.33s/it]
#                  all          9         95     0.0023     0.0256   0.000913   0.000165
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     25/149        0G    0.1172   0.06785   0.02784       197       416: 100% 2/2 [00:18<00:00,  9.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.33s/it]
#                  all          9         95    0.00223     0.0256   0.000907   0.000185
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     26/149        0G    0.1159   0.06888   0.02683       206       416: 100% 2/2 [00:18<00:00,  9.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.37s/it]
#                  all          9         95    0.00228     0.0513   0.000983   0.000171
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     27/149        0G    0.1154     0.075   0.02711       312       416: 100% 2/2 [00:18<00:00,  9.31s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.52s/it]
#                  all          9         95     0.0018     0.0256   0.000954   0.000168
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     28/149        0G    0.1159   0.06577   0.02756       206       416: 100% 2/2 [00:18<00:00,  9.32s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.54s/it]
#                  all          9         95     0.0027     0.0602    0.00117    0.00014
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     29/149        0G    0.1154   0.07287   0.02719       310       416: 100% 2/2 [00:18<00:00,  9.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.62s/it]
#                  all          9         95    0.00207     0.0563    0.00107   0.000154
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     30/149        0G    0.1152   0.06745   0.02703       265       416: 100% 2/2 [00:18<00:00,  9.28s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.81s/it]
#                  all          9         95    0.00231     0.0307   0.000865   0.000134
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     31/149        0G    0.1163   0.07787   0.02727       225       416: 100% 2/2 [00:18<00:00,  9.33s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.88s/it]
#                  all          9         95    0.00266    0.00893   0.000678   0.000136
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     32/149        0G    0.1139    0.0637     0.027       210       416: 100% 2/2 [00:18<00:00,  9.41s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.01s/it]
#                  all          9         95    0.00428     0.0217    0.00139   0.000284
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     33/149        0G    0.1114   0.05673   0.02655       164       416: 100% 2/2 [00:18<00:00,  9.34s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.99s/it]
#                  all          9         95      0.003    0.00893   0.000935   0.000204
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     34/149        0G    0.1128   0.06324   0.02656       253       416: 100% 2/2 [00:18<00:00,  9.32s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.01s/it]
#                  all          9         95     0.0104    0.00893    0.00151   0.000237
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     35/149        0G    0.1124   0.06512   0.02602       182       416: 100% 2/2 [00:18<00:00,  9.45s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.09s/it]
#                  all          9         95    0.00412     0.0217    0.00181   0.000292
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     36/149        0G    0.1123   0.07243   0.02631       167       416: 100% 2/2 [00:18<00:00,  9.44s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.15s/it]
#                  all          9         95    0.00569     0.0179    0.00197   0.000331
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     37/149        0G    0.1092   0.05827    0.0257       158       416: 100% 2/2 [00:18<00:00,  9.38s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.27s/it]
#                  all          9         95    0.00802    0.00893    0.00174   0.000272
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     38/149        0G    0.1122   0.05999   0.02553       174       416: 100% 2/2 [00:18<00:00,  9.46s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.33s/it]
#                  all          9         95    0.00569    0.00893    0.00188   0.000298
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     39/149        0G    0.1107   0.07625    0.0261       284       416: 100% 2/2 [00:18<00:00,  9.43s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.36s/it]
#                  all          9         95     0.0043     0.0396    0.00194   0.000341
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     40/149        0G    0.1117   0.06168    0.0258       199       416: 100% 2/2 [00:18<00:00,  9.38s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.50s/it]
#                  all          9         95    0.00568     0.0396    0.00177   0.000267
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     41/149        0G    0.1132   0.08718   0.02528       309       416: 100% 2/2 [00:19<00:00,  9.67s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.64s/it]
#                  all          9         95    0.00573     0.0217    0.00191   0.000306
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     42/149        0G    0.1107   0.07347   0.02425       224       416: 100% 2/2 [00:19<00:00,  9.86s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.74s/it]
#                  all          9         95    0.00549      0.153    0.00325   0.000697
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     43/149        0G    0.1083    0.0653   0.02557       233       416: 100% 2/2 [00:19<00:00,  9.75s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.85s/it]
#                  all          9         95     0.0101     0.0179    0.00342   0.000772
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     44/149        0G    0.1106   0.06466   0.02532       112       416: 100% 2/2 [00:19<00:00,  9.80s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.01s/it]
#                  all          9         95     0.0196     0.0179    0.00387   0.000753
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     45/149        0G    0.1125   0.07643   0.02527       296       416: 100% 2/2 [00:19<00:00,  9.78s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.14s/it]
#                  all          9         95     0.0453     0.0357     0.0176    0.00218
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     46/149        0G    0.1081   0.05362   0.02452       188       416: 100% 2/2 [00:19<00:00,  9.68s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.23s/it]
#                  all          9         95     0.0472     0.0357      0.023    0.00355
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     47/149        0G    0.1098   0.07314   0.02408       244       416: 100% 2/2 [00:19<00:00,  9.74s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.26s/it]
#                  all          9         95     0.0463     0.0357     0.0146    0.00284
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     48/149        0G    0.1092   0.07371   0.02459       240       416: 100% 2/2 [00:19<00:00,  9.71s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.37s/it]
#                  all          9         95     0.0524     0.0357     0.0153    0.00368
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     49/149        0G    0.1055   0.05406   0.02352        91       416: 100% 2/2 [00:19<00:00,  9.65s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.48s/it]
#                  all          9         95     0.0235     0.0792    0.00466      0.001
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     50/149        0G    0.1073   0.07557    0.0237       182       416: 100% 2/2 [00:19<00:00,  9.76s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.38s/it]
#                  all          9         95     0.0175      0.106    0.00567    0.00102
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     51/149        0G    0.1078   0.06301     0.025       188       416: 100% 2/2 [00:19<00:00,  9.69s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.40s/it]
#                  all          9         95      0.583     0.0179     0.0098    0.00271
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     52/149        0G    0.1076    0.0632    0.0251       204       416: 100% 2/2 [00:19<00:00,  9.62s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.46s/it]
#                  all          9         95      0.025     0.0446     0.0119    0.00323
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     53/149        0G    0.1082   0.06496   0.02434       270       416: 100% 2/2 [00:19<00:00,  9.62s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.52s/it]
#                  all          9         95     0.0279     0.0446     0.0119    0.00308
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     54/149        0G    0.1064   0.06838   0.02343       183       416: 100% 2/2 [00:19<00:00,  9.55s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.58s/it]
#                  all          9         95     0.0255     0.0971     0.0124    0.00307
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     55/149        0G      0.11   0.07357   0.02393       345       416: 100% 2/2 [00:18<00:00,  9.44s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.58s/it]
#                  all          9         95     0.0251     0.0881     0.0119    0.00273
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     56/149        0G    0.1052   0.06303   0.02411       143       416: 100% 2/2 [00:19<00:00,  9.66s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.80s/it]
#                  all          9         95     0.0695     0.0357     0.0152    0.00333
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     57/149        0G    0.1095   0.07373   0.02388       326       416: 100% 2/2 [00:19<00:00,  9.77s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.86s/it]
#                  all          9         95     0.0657     0.0446     0.0171    0.00334
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     58/149        0G    0.1057   0.06589   0.02258       191       416: 100% 2/2 [00:19<00:00,  9.65s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.82s/it]
#                  all          9         95     0.0686     0.0525     0.0192    0.00288
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     59/149        0G    0.1078    0.0693   0.02395       220       416: 100% 2/2 [00:19<00:00,  9.69s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.75s/it]
#                  all          9         95     0.0564     0.0536     0.0166    0.00266
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     60/149        0G    0.1042   0.06838   0.02363       237       416: 100% 2/2 [00:19<00:00,  9.65s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.75s/it]
#                  all          9         95      0.586     0.0536     0.0213    0.00354
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     61/149        0G    0.1045   0.06847   0.02269       240       416: 100% 2/2 [00:19<00:00,  9.63s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.82s/it]
#                  all          9         95      0.607     0.0625     0.0283    0.00464
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     62/149        0G    0.1037   0.07956   0.02392       205       416: 100% 2/2 [00:19<00:00,  9.83s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.77s/it]
#                  all          9         95      0.632     0.0625     0.0321    0.00513
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     63/149        0G    0.1036   0.07083    0.0215       160       416: 100% 2/2 [00:19<00:00,  9.66s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.81s/it]
#                  all          9         95      0.621     0.0714      0.036    0.00519
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     64/149        0G    0.1045   0.07398   0.02269       270       416: 100% 2/2 [00:19<00:00,  9.60s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.79s/it]
#                  all          9         95      0.624      0.071     0.0355    0.00533
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     65/149        0G    0.1071   0.07294   0.02286       308       416: 100% 2/2 [00:19<00:00,  9.66s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.73s/it]
#                  all          9         95      0.655       0.08     0.0438    0.00659
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     66/149        0G    0.1061   0.07362   0.02295       236       416: 100% 2/2 [00:19<00:00,  9.61s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.71s/it]
#                  all          9         95      0.659     0.0804      0.046     0.0064
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     67/149        0G    0.1015   0.07668   0.02265       228       416: 100% 2/2 [00:19<00:00,  9.70s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.73s/it]
#                  all          9         95     0.0983      0.116     0.0587     0.0082
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     68/149        0G    0.1033   0.05626   0.02286       231       416: 100% 2/2 [00:18<00:00,  9.49s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.60s/it]
#                  all          9         95      0.588      0.107     0.0477    0.00727
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     69/149        0G    0.1038   0.05012   0.02263       171       416: 100% 2/2 [00:18<00:00,  9.44s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.45s/it]
#                  all          9         95      0.724     0.0804     0.0573    0.00828
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     70/149        0G    0.1005   0.05902   0.02111       144       416: 100% 2/2 [00:18<00:00,  9.29s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.43s/it]
#                  all          9         95      0.716     0.0883      0.068     0.0095
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     71/149        0G    0.1019   0.06992   0.02197       303       416: 100% 2/2 [00:19<00:00,  9.72s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.34s/it]
#                  all          9         95      0.672     0.0804     0.0619     0.0102
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     72/149        0G   0.09937   0.06489   0.02101       192       416: 100% 2/2 [00:19<00:00,  9.65s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:06<00:00,  6.04s/it]
#                  all          9         95      0.613      0.134     0.0634      0.011
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     73/149        0G    0.1022   0.08134   0.02236       266       416: 100% 2/2 [00:18<00:00,  9.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.88s/it]
#                  all          9         95      0.616      0.125     0.0652     0.0121
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     74/149        0G   0.09536   0.05127   0.02073       140       416: 100% 2/2 [00:19<00:00,  9.73s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.73s/it]
#                  all          9         95      0.645      0.125      0.077     0.0158
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     75/149        0G    0.1014   0.08146   0.02245       298       416: 100% 2/2 [00:19<00:00,  9.64s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.70s/it]
#                  all          9         95      0.667      0.143     0.0948     0.0177
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     76/149        0G   0.09795   0.05516   0.01987       185       416: 100% 2/2 [00:18<00:00,  9.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.55s/it]
#                  all          9         95      0.653      0.134     0.0868     0.0194
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     77/149        0G    0.1029   0.06759   0.02176       306       416: 100% 2/2 [00:18<00:00,  9.50s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.45s/it]
#                  all          9         95      0.629      0.134     0.0845     0.0156
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     78/149        0G   0.09557   0.06756    0.0209       196       416: 100% 2/2 [00:18<00:00,  9.49s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.37s/it]
#                  all          9         95      0.629      0.142     0.0857     0.0185
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     79/149        0G   0.09823   0.07087   0.02091       234       416: 100% 2/2 [00:19<00:00,  9.71s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.35s/it]
#                  all          9         95      0.651      0.116     0.0818     0.0182
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     80/149        0G   0.09872   0.07703   0.02029       256       416: 100% 2/2 [00:19<00:00,  9.59s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.12s/it]
#                  all          9         95      0.618      0.161      0.087     0.0162
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     81/149        0G    0.1004    0.0767   0.02103       372       416: 100% 2/2 [00:19<00:00,  9.54s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.07s/it]
#                  all          9         95      0.605      0.152     0.0799     0.0167
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     82/149        0G   0.09578   0.07148    0.0204       234       416: 100% 2/2 [00:18<00:00,  9.43s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:05<00:00,  5.04s/it]
#                  all          9         95      0.612      0.161     0.0835     0.0174
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     83/149        0G   0.09742   0.07276   0.02132       253       416: 100% 2/2 [00:18<00:00,  9.43s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.92s/it]
#                  all          9         95       0.62      0.169     0.0905     0.0161
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     84/149        0G    0.0964   0.06304   0.02088       234       416: 100% 2/2 [00:19<00:00,  9.54s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.99s/it]
#                  all          9         95      0.622       0.17     0.0907     0.0176
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     85/149        0G   0.09712   0.07157   0.02066       208       416: 100% 2/2 [00:18<00:00,  9.40s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.91s/it]
#                  all          9         95      0.633       0.17     0.0984     0.0174
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     86/149        0G   0.09633   0.06468   0.02087       209       416: 100% 2/2 [00:19<00:00,  9.67s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.83s/it]
#                  all          9         95      0.628       0.16     0.0919     0.0214
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     87/149        0G     0.099   0.06361   0.02162       223       416: 100% 2/2 [00:18<00:00,  9.41s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.75s/it]
#                  all          9         95      0.627      0.161     0.0902     0.0206
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     88/149        0G   0.09662   0.06921   0.02139       262       416: 100% 2/2 [00:18<00:00,  9.28s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.71s/it]
#                  all          9         95      0.625      0.161     0.0884     0.0209
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     89/149        0G   0.09677   0.05364   0.02085       210       416: 100% 2/2 [00:18<00:00,  9.40s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.62s/it]
#                  all          9         95      0.607      0.205     0.0891      0.021
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     90/149        0G   0.09674   0.05435   0.02074       203       416: 100% 2/2 [00:18<00:00,  9.43s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.57s/it]
#                  all          9         95       0.63       0.17     0.0975      0.023
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     91/149        0G   0.09286   0.06145   0.02108       172       416: 100% 2/2 [00:18<00:00,  9.46s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.62s/it]
#                  all          9         95      0.626      0.179     0.0986       0.02
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     92/149        0G    0.0926   0.06075   0.02129       240       416: 100% 2/2 [00:18<00:00,  9.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.56s/it]
#                  all          9         95      0.642      0.188       0.11     0.0238
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     93/149        0G   0.09305   0.05846   0.02136       123       416: 100% 2/2 [00:18<00:00,  9.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.48s/it]
#                  all          9         95      0.631      0.196      0.109     0.0215
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     94/149        0G   0.09653   0.06172   0.02049       206       416: 100% 2/2 [00:18<00:00,  9.31s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.46s/it]
#                  all          9         95      0.676      0.152      0.109     0.0242
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     95/149        0G   0.09392   0.06907    0.0203       255       416: 100% 2/2 [00:19<00:00,  9.57s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.36s/it]
#                  all          9         95      0.653      0.188      0.112     0.0231
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     96/149        0G   0.09281   0.07068   0.01958       261       416: 100% 2/2 [00:19<00:00,  9.54s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.48s/it]
#                  all          9         95      0.656      0.179      0.111     0.0246
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     97/149        0G   0.09306   0.04968   0.02117       163       416: 100% 2/2 [00:19<00:00,  9.56s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.28s/it]
#                  all          9         95      0.649      0.188      0.116     0.0279
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     98/149        0G   0.09226   0.07258    0.0196       200       416: 100% 2/2 [00:19<00:00,  9.57s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.38s/it]
#                  all          9         95      0.649      0.188      0.118     0.0263
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     99/149        0G   0.09538   0.05918   0.02128       215       416: 100% 2/2 [00:18<00:00,  9.34s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.22s/it]
#                  all          9         95      0.651      0.178       0.12     0.0232
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    100/149        0G   0.09176   0.06723   0.01979       187       416: 100% 2/2 [00:18<00:00,  9.33s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.23s/it]
#                  all          9         95      0.635      0.186      0.104     0.0253
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    101/149        0G   0.09472   0.06494   0.02052       271       416: 100% 2/2 [00:18<00:00,  9.46s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.25s/it]
#                  all          9         95      0.645      0.168      0.111     0.0238
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    102/149        0G   0.09458   0.07248   0.01895       314       416: 100% 2/2 [00:18<00:00,  9.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.17s/it]
#                  all          9         95      0.641      0.169      0.109     0.0219
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    103/149        0G    0.0949   0.07152   0.01964       302       416: 100% 2/2 [00:19<00:00,  9.63s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.28s/it]
#                  all          9         95      0.618      0.205      0.108     0.0209
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    104/149        0G   0.09114   0.06263   0.02139       156       416: 100% 2/2 [00:19<00:00,  9.76s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.13s/it]
#                  all          9         95      0.626      0.196      0.112     0.0233
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    105/149        0G   0.09264   0.06061   0.01939       213       416: 100% 2/2 [00:19<00:00,  9.68s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.19s/it]
#                  all          9         95      0.623      0.205      0.114     0.0227
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    106/149        0G   0.09369   0.07422   0.01973       262       416: 100% 2/2 [00:18<00:00,  9.33s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.03s/it]
#                  all          9         95      0.634      0.196      0.113     0.0234
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    107/149        0G   0.09354   0.06625   0.01972       241       416: 100% 2/2 [00:18<00:00,  9.39s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.98s/it]
#                  all          9         95      0.628      0.205      0.108     0.0226
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    108/149        0G     0.093   0.07312   0.02008       246       416: 100% 2/2 [00:18<00:00,  9.46s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.03s/it]
#                  all          9         95      0.626      0.223     0.0965     0.0218
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
# ...
#                  all          9         95      0.639      0.196      0.116     0.0255
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    111/149        0G   0.09604   0.06065   0.02171       243       416: 100% 2/2 [00:18<00:00,  9.41s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.97s/it]
#                  all          9         95       0.63      0.232       0.12     0.0266
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    112/149        0G   0.09031   0.06371   0.01859       181       416: 100% 2/2 [00:18<00:00,  9.33s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.94s/it]
#                  all          9         95      0.628       0.25       0.12     0.0268
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    113/149        0G   0.08976   0.06356   0.01999       176       416: 100% 2/2 [00:19<00:00,  9.51s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.92s/it]
#                  all          9         95      0.701      0.152      0.119     0.0259
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    114/149        0G   0.09282   0.06603   0.01918       194       416: 100% 2/2 [00:18<00:00,  9.32s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.92s/it]
#                  all          9         95      0.698      0.152      0.116     0.0267
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    115/149        0G   0.09222   0.07487   0.02066       305       416: 100% 2/2 [00:18<00:00,  9.28s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.89s/it]
#                  all          9         95      0.704      0.161       0.12     0.0261
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    116/149        0G   0.09316   0.06834   0.01976       182       416: 100% 2/2 [00:19<00:00,  9.68s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:04<00:00,  4.00s/it]
#                  all          9         95      0.703      0.161       0.12     0.0264
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    117/149        0G    0.0915   0.05929   0.02021       218       416: 100% 2/2 [00:19<00:00,  9.69s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.87s/it]
#                  all          9         95      0.712      0.152       0.12     0.0304
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    118/149        0G   0.09014   0.07526   0.01945       195       416: 100% 2/2 [00:19<00:00,  9.51s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.90s/it]
#                  all          9         95      0.712      0.152      0.118     0.0301
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    119/149        0G   0.09218   0.06295   0.01931       205       416: 100% 2/2 [00:18<00:00,  9.46s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.85s/it]
#                  all          9         95      0.703      0.159      0.123     0.0276
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    120/149        0G   0.09023   0.06186   0.01932       239       416: 100% 2/2 [00:18<00:00,  9.49s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.86s/it]
#                  all          9         95      0.709      0.161      0.124     0.0288
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    121/149        0G    0.0893   0.06276   0.01863       213       416: 100% 2/2 [00:18<00:00,  9.31s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.82s/it]
#                  all          9         95      0.724       0.16      0.128     0.0282
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    122/149        0G   0.08903   0.07072   0.01884       176       416: 100% 2/2 [00:18<00:00,  9.45s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.88s/it]
#                  all          9         95       0.72      0.161      0.127     0.0303
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    123/149        0G   0.09219   0.06202   0.02002       194       416: 100% 2/2 [00:19<00:00,  9.61s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.88s/it]
#                  all          9         95      0.719       0.16      0.128     0.0324
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    124/149        0G   0.08878   0.06684   0.01809       222       416: 100% 2/2 [00:18<00:00,  9.31s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.79s/it]
#                  all          9         95      0.736      0.152       0.13     0.0323
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    125/149        0G   0.08734   0.06263   0.01893       140       416: 100% 2/2 [00:18<00:00,  9.43s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.84s/it]
#                  all          9         95      0.683      0.186       0.13     0.0327
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    126/149        0G   0.08776   0.05093   0.02097       150       416: 100% 2/2 [00:19<00:00,  9.68s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.75s/it]
#                  all          9         95       0.72       0.17      0.141     0.0366
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    127/149        0G    0.0878   0.06988   0.01889       305       416: 100% 2/2 [00:19<00:00,  9.56s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.77s/it]
#                  all          9         95      0.724      0.161      0.146     0.0369
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    128/149        0G   0.09065   0.06108   0.01903       140       416: 100% 2/2 [00:18<00:00,  9.42s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.75s/it]
#                  all          9         95      0.731      0.161      0.144     0.0418
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    129/149        0G   0.08683   0.06083   0.01806       197       416: 100% 2/2 [00:19<00:00,  9.75s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.68s/it]
#                  all          9         95       0.73      0.161      0.148     0.0403
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    130/149        0G   0.08516   0.06113   0.01914       198       416: 100% 2/2 [00:18<00:00,  9.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.57s/it]
#                  all          9         95      0.749       0.17      0.153     0.0447
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    131/149        0G   0.08967   0.07989   0.01767       296       416: 100% 2/2 [00:18<00:00,  9.26s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.56s/it]
#                  all          9         95       0.68      0.196      0.147     0.0367
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    132/149        0G   0.08951   0.06056   0.02065       231       416: 100% 2/2 [00:19<00:00,  9.55s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.65s/it]
#                  all          9         95       0.69      0.205      0.153      0.039
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    133/149        0G   0.09005   0.05924   0.01916       176       416: 100% 2/2 [00:19<00:00,  9.51s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.62s/it]
#                  all          9         95      0.691      0.205      0.153     0.0386
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    134/149        0G   0.08638   0.05089   0.01847       141       416: 100% 2/2 [00:18<00:00,  9.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.64s/it]
#                  all          9         95      0.653       0.24      0.144     0.0406
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    135/149        0G    0.0901   0.07159   0.01913       280       416: 100% 2/2 [00:18<00:00,  9.43s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.59s/it]
#                  all          9         95      0.648      0.241       0.14      0.039
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    136/149        0G   0.09034    0.0616   0.02029       177       416: 100% 2/2 [00:18<00:00,  9.32s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.50s/it]
#                  all          9         95      0.688      0.205      0.146     0.0406
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    137/149        0G   0.08799   0.05956   0.01939       131       416: 100% 2/2 [00:18<00:00,  9.31s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.52s/it]
#                  all          9         95      0.682      0.205      0.139     0.0352
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    138/149        0G   0.08625   0.07855   0.01954       312       416: 100% 2/2 [00:18<00:00,  9.20s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.54s/it]
#                  all          9         95      0.685      0.205      0.141     0.0369
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    139/149        0G   0.09043   0.06098   0.01859       273       416: 100% 2/2 [00:19<00:00,  9.58s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.44s/it]
#                  all          9         95      0.664      0.249      0.142     0.0357
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    140/149        0G    0.0861   0.06596   0.01948       233       416: 100% 2/2 [00:19<00:00,  9.67s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.55s/it]
#                  all          9         95      0.695      0.205      0.146     0.0414
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    141/149        0G   0.08712   0.07122    0.0187       254       416: 100% 2/2 [00:19<00:00,  9.56s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.57s/it]
#                  all          9         95      0.703      0.214      0.158     0.0365
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    142/149        0G    0.0902   0.07099   0.01933       264       416: 100% 2/2 [00:18<00:00,  9.33s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.39s/it]
#                  all          9         95      0.744      0.188      0.165     0.0416
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    143/149        0G   0.08493   0.06509    0.0177       283       416: 100% 2/2 [00:18<00:00,  9.39s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.38s/it]
#                  all          9         95      0.738      0.188      0.168     0.0395
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    144/149        0G   0.09022   0.07391   0.01968       352       416: 100% 2/2 [00:18<00:00,  9.50s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.50s/it]
#                  all          9         95      0.722      0.214      0.172     0.0417
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    145/149        0G   0.08833   0.07346   0.01946       276       416: 100% 2/2 [00:19<00:00,  9.65s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.47s/it]
#                  all          9         95      0.762      0.188      0.179     0.0446
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    146/149        0G   0.08953    0.0592   0.01901       237       416: 100% 2/2 [00:19<00:00,  9.75s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.45s/it]
#                  all          9         95      0.769      0.188      0.181     0.0473
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    147/149        0G   0.08844   0.05945    0.0201       180       416: 100% 2/2 [00:18<00:00,  9.49s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.32s/it]
#                  all          9         95      0.735      0.214      0.186     0.0486
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    148/149        0G   0.08636   0.07484   0.01785       240       416: 100% 2/2 [00:18<00:00,  9.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.39s/it]
#                  all          9         95      0.729      0.205      0.176     0.0486
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    149/149        0G   0.08621   0.06929   0.01909       196       416: 100% 2/2 [00:19<00:00,  9.77s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.44s/it]
#                  all          9         95      0.735      0.214      0.183     0.0495
#
# 150 epochs completed in 1.004 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 14.3MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 14.3MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:03<00:00,  3.77s/it]
#                  all          9         95      0.731      0.214      0.178     0.0491
#               Debris          9         39          1          0     0.0132    0.00312
#          Encampments          9         56      0.461      0.429      0.342     0.0951
# Results saved to runs/train/exp
# CPU times: user 29.7 s, sys: 4.46 s, total: 34.2 s
# Wall time: 1h 44s

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
#saving weights

# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source {dataset.location}/test/images
# Out:
# python3: can't open file 'detect.py': [Errno 2] No such file or directory
